# %%
# %sql
CREATE SCHEMA IF NOT EXISTS raw;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create Metadata Control Table in raw schema
CREATE TABLE IF NOT EXISTS raw.ingestion_metadata (
    execution_order INT,
    resource_name STRING,
    days_back INT,
    is_active BOOLEAN
) USING DELTA;

-- Seed Metadata Control Table (Strict Order: Patient -> Encounter -> Observation -> Condition)
TRUNCATE TABLE raw.ingestion_metadata;

INSERT INTO raw.ingestion_metadata VALUES
(1, 'Patient', 3, true),
(2, 'Encounter', 3, true),
(3, 'Observation', 3, true),
(4, 'Condition', 3, true);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>
